# %%
import cv2
import os
from dotenv import load_dotenv

load_dotenv()

ML_Summer_School_ID = os.getenv('ML_Summer_School_ID')
print("Your Sudent ID is: " + ML_Summer_School_ID)
# Out:
# Your Sudent ID is: ML037_Hnin_Ei_Khaing

# %%
import random
import matplotlib.pyplot as plt

test_img_path = "./test_dataset/sample_data"
os.listdir(test_img_path)
# Out:
# ['1.jpeg', '8.png', '4.jpg', '5.jpg', '7.png', '6.jpg', '2.jpg', '3.jpg']

# %%
selected_img = random.choice(os.listdir(test_img_path))
print("selected_img : " + selected_img)



selected_img_full_path = test_img_path+"/"+selected_img

print("selected_img_full_path : ",selected_img_full_path)

read_img = cv2.imread(selected_img_full_path)
if read_img is None:
    print("Image not found")


resize_img = cv2.resize(read_img,(300,300))
plt.imshow(resize_img)
# Out:
# selected_img : 3.jpg
# selected_img_full_path :  ./test_dataset/sample_data/3.jpg

# %%
# Write your image into data_annotated folder
write_name = f"./data_annotated/{ML_Summer_School_ID}.png"
cv2.imwrite(write_name, resize_img)
# Out:
# True

# %%
pip install labelme
# Out:
# Collecting labelme
#   Downloading labelme-5.8.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting imgviz (from labelme)
#   Downloading imgviz-1.7.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting loguru (from labelme)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from labelme) (3.10.3)
# Collecting natsort>=7.1.0 (from labelme)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from labelme) (2.0.2)
# Collecting osam>=0.2.3 (from labelme)
#   Downloading osam-0.2.4-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pillow>=2.8 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from labelme) (11.3.0)
# Collecting pyqt5>=5.14.0 (from labelme)
#   Downloading PyQt5-5.15.11-cp38-abi3-macosx_11_0_x86_64.whl.metadata (2.1 kB)
# Collecting pyyaml (from labelme)
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting scikit-image (from labelme)
#   Downloading scikit_image-0.25.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (14 kB)
# Collecting click (from osam>=0.2.3->labelme)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting gdown (from osam>=0.2.3->labelme)
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1 (from osam>=0.2.3->labelme)
#   Downloading onnxruntime-1.22.1-cp310-cp310-macosx_13_0_universal2.whl.metadata (4.6 kB)
# Collecting pydantic (from osam>=0.2.3->labelme)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting coloredlogs (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: packaging in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (25.0)
# Collecting protobuf (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting sympy (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5>=5.14.0->labelme)
#   Downloading PyQt5_sip-12.17.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5>=5.14.0->labelme)
#   Downloading PyQt5_Qt5-5.15.17-py3-none-macosx_10_13_x86_64.whl.metadata (536 bytes)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting beautifulsoup4 (from gdown->osam>=0.2.3->labelme)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting filelock (from gdown->osam>=0.2.3->labelme)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests[socks] (from gdown->osam>=0.2.3->labelme)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from gdown->osam>=0.2.3->labelme)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown->osam>=0.2.3->labelme)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from beautifulsoup4->gdown->osam>=0.2.3->labelme) (4.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib->labelme) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/hnineikhaing/opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.17.0)
# Collecting annotated-types>=0.6.0 (from pydantic->osam>=0.2.3->labelme)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic->osam>=0.2.3->labelme)
#   Downloading pydantic_core-2.33.2-cp310-cp310-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic->osam>=0.2.3->labelme)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests[socks]->gdown->osam>=0.2.3->labelme)
#   Downloading charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests[socks]->gdown->osam>=0.2.3->labelme)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests[socks]->gdown->osam>=0.2.3->labelme)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests[socks]->gdown->osam>=0.2.3->labelme)
#   Downloading certifi-2025.7.9-py3-none-any.whl.metadata (2.4 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->osam>=0.2.3->labelme)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting scipy>=1.11.4 (from scikit-image->labelme)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_10_13_x86_64.whl.metadata (61 kB)
# Collecting networkx>=3.0 (from scikit-image->labelme)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->labelme)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->labelme)
#   Downloading tifffile-2025.5.10-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->labelme)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading labelme-5.8.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.6 MB/s eta 0:00:00
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading osam-0.2.4-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.2 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.1-cp310-cp310-macosx_13_0_universal2.whl (34.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 16.9 MB/s eta 0:00:00a 0:00:01
# Downloading PyQt5-5.15.11-cp38-abi3-macosx_11_0_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading PyQt5_Qt5-5.15.17-py3-none-macosx_10_13_x86_64.whl (40.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 15.7 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_sip-12.17.0-cp310-cp310-macosx_10_9_universal2.whl (122 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading imgviz-1.7.6-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 14.3 MB/s eta 0:00:00a 0:00:01
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading protobuf-6.31.1-cp39-abi3-macosx_10_9_universal2.whl (425 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-macosx_10_12_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.2 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-macosx_10_9_x86_64.whl (184 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl (201 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.7.9-py3-none-any.whl (159 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading scikit_image-0.25.2-cp310-cp310-macosx_10_9_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.15.3-cp310-cp310-macosx_10_13_x86_64.whl (38.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.7/38.7 MB 9.5 MB/s eta 0:00:00a 0:00:01
# Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 13.9 MB/s eta 0:00:00a 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 11.8 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: PyQt5-Qt5, mpmath, flatbuffers, urllib3, typing-inspection, tqdm, tifffile, sympy, soupsieve, scipy, pyyaml, PySocks, PyQt5-sip, pydantic-core, protobuf, networkx, natsort, loguru, lazy-loader, imageio, idna, humanfriendly, filelock, click, charset_normalizer, certifi, annotated-types, scikit-image, requests, pyqt5, pydantic, coloredlogs, beautifulsoup4, onnxruntime, imgviz, gdown, osam, labelme
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38/38 [labelme]7/38 [labelme]ime]p4]
# Successfully installed PyQt5-Qt5-5.15.17 PyQt5-sip-12.17.0 PySocks-1.7.1 annotated-types-0.7.0 beautifulsoup4-4.13.4 certifi-2025.7.9 charset_normalizer-3.4.2 click-8.2.1 coloredlogs-15.0.1 filelock-3.18.0 flatbuffers-25.2.10 gdown-5.2.0 humanfriendly-10.0 idna-3.10 imageio-2.37.0 imgviz-1.7.6 labelme-5.8.2 lazy-loader-0.4 loguru-0.7.3 mpmath-1.3.0 natsort-8.4.0 networkx-3.4.2 onnxruntime-1.22.1 osam-0.2.4 protobuf-6.31.1 pydantic-2.11.7 pydantic-core-2.33.2 pyqt5-5.15.11 pyyaml-6.0.2 requests-2.32.4 scikit-image-0.25.2 scipy-1.15.3 soupsieve-2.7 sympy-1.14.0 tifffile-2025.5.10 tqdm-4.67.1 typing-inspection-0.4.1 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !labelme data_annotated
# Out:
# qt.qpa.window: Window position QRect(-177,73 954x459) outside any known screen, using primary screen
# 2025-07-11 11:41:28.758 python3.10[5564:958602] +[CATransaction synchronize] called within transaction
# 2025-07-11 11:41:28.765 python3.10[5564:958602] +[CATransaction synchronize] called within transaction
# 2025-07-11 11:41:31.795 python3.10[5564:958602] +[CATransaction synchronize] called within transaction
